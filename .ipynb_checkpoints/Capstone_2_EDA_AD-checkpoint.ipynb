# %%
#importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from library.sb_utils import save_file

# %%
#Loading the Cleaned file of our movie data-set
movies_revs = pd.read_csv(
    'tmdb_clean.csv',
    parse_dates=['release_date']
)

# %%
movies_revs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9981 entries, 0 to 9980
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              9981 non-null   object
#  1   adult              9981 non-null   bool
#  2   genres             9981 non-null   object
#  3   original_language  9981 non-null   object
#  4   popularity         9981 non-null   float64
#  5   release_date       9981 non-null   datetime64[ns]
#  6   runtime            9981 non-null   int64
#  7   vote_average       9981 non-null   float64
#  8   vote_count         9981 non-null   int64
#  9   actors             9981 non-null   object
#  10  director           9981 non-null   object
#  11  keywords           9981 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 867.6+ KB

# %%
movies_revs.head(10)
# Out:
#                           title  adult  \
# 0  Aquaman and the Lost Kingdom  False
# 1                         Wonka  False
# 2                          Wish  False
# 3                     Migration  False
# 4                   The Marvels  False
# 5                 Sixty Minutes  False
# 6                 Patriots Time  False
# 7                       Radical  False
# 8                        Attack  False
# 9                          Lift  False
#
#                                               genres original_language  \
# 0                 ['Action', 'Adventure', 'Fantasy']                en
# 1                    ['Comedy', 'Family', 'Fantasy']                en
# 2    ['Animation', 'Family', 'Fantasy', 'Adventure']                en
# 3  ['Animation', 'Adventure', 'Comedy', 'Family',...                en
# 4         ['Science Fiction', 'Adventure', 'Action']                en
# 5                                ['Action', 'Drama']                de
# 6                                  ['Action', 'War']                ru
# 7                                          ['Drama']                en
# 8          ['Action', 'Science Fiction', 'Thriller']                hi
# 9             ['Action', 'Comedy', 'Crime', 'Drama']                en
#
#    popularity release_date  runtime  vote_average  vote_count  \
# 0    5841.384   2023-12-20      124         7.013        1156
# 1    2333.391   2023-12-06      117         7.200        1660
# 2    1662.711   2023-11-13       95         6.638         538
# 3    1486.310   2023-12-06       83         7.830         390
# 4    1397.918   2023-11-08      105         6.415        1328
# 5    1028.278   2024-01-19       89         6.912         170
# 6     830.989   2022-04-28      101         9.700          16
# 7     774.377   2023-10-19      127         8.626         139
# 8     751.443   2022-04-01      123         7.412          85
# 9     740.964   2024-01-10      106         6.499         616
#
#                                               actors  \
# 0  ['Jason Momoa', 'Patrick Wilson', 'Yahya Abdul...
# 1  ['Timothée Chalamet', 'Calah Lane', 'Keegan-Mi...
# 2  ['Ariana DeBose', 'Chris Pine', 'Alan Tudyk', ...
# 3  ['Kumail Nanjiani', 'Elizabeth Banks', 'Caspar...
# 4  ['Brie Larson', 'Teyonah Parris', 'Iman Vellan...
# 5  ['Emilio Sakraya', 'Dennis Mojen', 'Marie Mour...
# 6  ['Daniyar Alshinov', 'Sanurzhan Suleymenov', '...
# 7  ['Eugenio Derbez', 'Daniel Haddad', 'Jennifer ...
# 8  ['John Abraham', 'Serena Walia', 'Rakul Preet ...
# 9  ['Kevin Hart', 'Gugu Mbatha-Raw', 'Sam Worthin...
#
#                     director  \
# 0              ['James Wan']
# 1              ['Paul King']
# 2             ['Chris Buck']
# 3        ['Benjamin Renner']
# 4            ['Nia DaCosta']
# 5          ['Oliver Kienle']
# 6  ['Serikbol Utepbergenov']
# 7      ['Christopher Zalla']
# 8      ['Lakshya Raj Anand']
# 9           ['F. Gary Gray']
#
#                                             keywords
# 0  ['superhero', 'secret society', 'half-brother'...
# 1  ['chocolate', 'musical', 'prequel', 'duringcre...
# 2  ['friendship', 'musical', 'computer animation'...
# 3  ['duck', 'migration', 'flight', 'anthropomorph...
# 4  ['hero', 'superhero', 'space travel', 'based o...
# 5                                                 []
# 6                                                 []
# 7  ['usa–mexico border', 'teachers and students',...
# 8  ['parliament', 'super soldier', 'soldier', 'in...
# 9  ['gold', 'gang of thieves', 'heist', 'airplane...

# %%
movies_revs.describe(include= 'all')
# Out:
#         title  adult     genres original_language   popularity  \
# count    9981   9981       9981              9981  9981.000000
# unique   9467      1       2288                53          NaN
# top     Porno  False  ['Drama']                en          NaN
# freq        5   9981        529              7482          NaN
# mean      NaN    NaN        NaN               NaN    29.631342
# min       NaN    NaN        NaN               NaN    12.674000
# 25%       NaN    NaN        NaN               NaN    15.125000
# 50%       NaN    NaN        NaN               NaN    19.194000
# 75%       NaN    NaN        NaN               NaN    28.301000
# max       NaN    NaN        NaN               NaN  5841.384000
# std       NaN    NaN        NaN               NaN    77.415196
#
#                          release_date      runtime  vote_average  \
# count                            9981  9981.000000   9981.000000
# unique                            NaN          NaN           NaN
# top                               NaN          NaN           NaN
# freq                              NaN          NaN           NaN
# mean    2007-05-02 12:17:57.727682816   101.753331      6.386695
# min               1902-04-17 00:00:00     0.000000      0.000000
# 25%               1999-10-06 00:00:00    91.000000      5.974000
# 50%               2012-06-23 00:00:00   101.000000      6.574000
# 75%               2020-02-27 00:00:00   115.000000      7.145000
# max               2031-12-18 00:00:00   400.000000     10.000000
# std                               NaN    27.882254      1.358012
#
#           vote_count actors director keywords
# count    9981.000000   9981     9981     9981
# unique           NaN   9584     4855     8485
# top              NaN     []       []       []
# freq             NaN     51       41      975
# mean     1653.566576    NaN      NaN      NaN
# min         0.000000    NaN      NaN      NaN
# 25%       168.000000    NaN      NaN      NaN
# 50%       576.000000    NaN      NaN      NaN
# 75%      1707.000000    NaN      NaN      NaN
# max     35168.000000    NaN      NaN      NaN
# std      3002.152905    NaN      NaN      NaN

# %%
#Quick check for nulls
movies_revs.isnull().sum()
# Out:
# title                0
# adult                0
# genres               0
# original_language    0
# popularity           0
# release_date         0
# runtime              0
# vote_average         0
# vote_count           0
# actors               0
# director             0
# keywords             0
# dtype: int64

# %%
#Checking for duplicates 
movies_revs.duplicated().sum()
# Out:
# 173

# %%
#Previewing the duplicated data and dropping them
movies_revs[movies_revs.duplicated(keep=False)].sort_values(by='title')
# Out:
#                                      title  adult  \
# 1683                        50 First Dates  False
# 1734                        50 First Dates  False
# 2820                            97 Minutes  False
# 2372                            97 Minutes  False
# 3335  A Cinderella Story: Once Upon a Song  False
# ...                                    ...    ...
# 2920                                Wonder  False
# 2357                     Y Tu Mamá También  False
# 2201                     Y Tu Mamá También  False
# 3337              sex, lies, and videotape  False
# 3117              sex, lies, and videotape  False
#
#                                genres original_language  popularity  \
# 1683            ['Comedy', 'Romance']                en      35.036
# 1734            ['Comedy', 'Romance']                en      35.036
# 2820  ['Action', 'Thriller', 'Drama']                en      26.577
# 2372  ['Action', 'Thriller', 'Drama']                en      26.577
# 3335  ['Comedy', 'Family', 'Romance']                en      24.766
# ...                               ...               ...         ...
# 2920              ['Drama', 'Family']                en      26.075
# 2357             ['Drama', 'Romance']                es      30.420
# 2201             ['Drama', 'Romance']                es      30.420
# 3337                        ['Drama']                en      25.083
# 3117                        ['Drama']                en      25.083
#
#      release_date  runtime  vote_average  vote_count  \
# 1683   2004-02-13       99         6.858        6854
# 1734   2004-02-13       99         6.858        6854
# 2820   2023-06-09       93         4.838          65
# 2372   2023-06-09       93         4.838          65
# 3335   2011-09-05       88         6.388         989
# ...           ...      ...           ...         ...
# 2920   2017-11-13      113         8.145        7563
# 2357   2001-06-08      106         7.400        1388
# 2201   2001-06-08      106         7.400        1388
# 3337   1989-08-04      101         7.000         825
# 3117   1989-08-04      101         7.000         825
#
#                                                  actors  \
# 1683  ['Adam Sandler', 'Drew Barrymore', 'Rob Schnei...
# 1734  ['Adam Sandler', 'Drew Barrymore', 'Rob Schnei...
# 2820  ['Jonathan Rhys Meyers', 'Alec Baldwin', 'MyAn...
# 2372  ['Jonathan Rhys Meyers', 'Alec Baldwin', 'MyAn...
# 3335  ['Lucy Hale', 'Freddie Stroma', 'Missi Pyle', ...
# ...                                                 ...
# 2920  ['Jacob Tremblay', 'Julia Roberts', 'Owen Wils...
# 2357  ['Gael García Bernal', 'Diego Luna', 'Maribel ...
# 2201  ['Gael García Bernal', 'Diego Luna', 'Maribel ...
# 3337  ['Andie MacDowell', 'Peter Gallagher', 'James ...
# 3117  ['Andie MacDowell', 'Peter Gallagher', 'James ...
#
#                     director  \
# 1683         ['Peter Segal']
# 1734         ['Peter Segal']
# 2820     ['Timo Vuorensola']
# 2372     ['Timo Vuorensola']
# 3335  ['Damon Santostefano']
# ...                      ...
# 2920     ['Stephen Chbosky']
# 2357      ['Alfonso Cuarón']
# 2201      ['Alfonso Cuarón']
# 3337   ['Steven Soderbergh']
# 3117   ['Steven Soderbergh']
#
#                                                keywords
# 1683  ['sailboat', 'friendship', 'beach', 'deja vu',...
# 1734  ['sailboat', 'friendship', 'beach', 'deja vu',...
# 2820                                                 []
# 2372                                                 []
# 3335  ['high school', 'aspiring singer', 'orphan', '...
# ...                                                 ...
# 2920  ['exclusion', 'bullying', 'coney island', 'pre...
# 2357  ['adolescence', 'beach', 'mexico', 'group sex'...
# 2201  ['adolescence', 'beach', 'mexico', 'group sex'...
# 3337  ['sexual obsession', 'sexuality', 'orgasm', 's...
# 3117  ['sexual obsession', 'sexuality', 'orgasm', 's...
#
# [346 rows x 12 columns]

# %%
movies_revs = movies_revs.drop_duplicates()

# %%
print(f"Duplicates remaining: {movies_revs.duplicated().sum()}")
# Out:
# Duplicates remaining: 0

# %%
#Starting with Univariate Analysis
movies_revs.select_dtypes(include ='number').columns
# Out:
# Index(['popularity', 'runtime', 'vote_average', 'vote_count'], dtype='object')

# %%
#Using the describe() function on numeric columns 
movies_revs[['popularity','runtime','vote_average','vote_count']].describe()
# Out:
#         popularity      runtime  vote_average    vote_count
# count  9808.000000  9808.000000   9808.000000   9808.000000
# mean     29.465235   101.802202      6.387273   1642.683931
# std      77.958201    27.838553      1.352642   3001.293190
# min      12.674000     0.000000      0.000000      0.000000
# 25%      15.074750    91.000000      5.972000    168.000000
# 50%      19.035500   101.000000      6.570000    571.000000
# 75%      28.072750   115.000000      7.145000   1691.500000
# max    5841.384000   400.000000     10.000000  35168.000000

# %%
runtime_medians = movies_revs[movies_revs['runtime'] != 0]['runtime'].median()
movies_revs['runtime_for_plot'] = movies_revs['runtime'].replace(0, runtime_medians)

# %%
(movies_revs['runtime_for_plot'] == 0).sum()
# Out:
# 0

# %%
#Since there are movies with no voting averages, instead of filling them with median which could be misleading for our analysis, we filter the rows.
(movies_revs['vote_average'] == 0.000).sum()
# Out:
# 242

# %%
movies_cleaned = movies_revs[movies_revs['vote_average'] > 0 ]
(movies_cleaned['vote_average'] == 0.000).sum()
# Out:
# 0

# %%
#Now since we replaced the '0's with median values for runtime and filtered vote_averages, lets plot a scatterplot to see if 'runtime'has any effect on 'voting average'.

plt.figure(figsize = (10,6))
sns.scatterplot(data=movies_cleaned, x ='runtime_for_plot', y='vote_average', alpha =0.5)
plt.title('Does runtime affect ratings?')
plt.xlabel('runtime')
plt.ylabel('vote_average')
plt.grid(True)
plt.show()

# %%
#Creating a top movies data frame which we will use to merge with actor_summary to have a deeper look.
top_rating = movies_cleaned['vote_average'].max()
top_movies = movies_cleaned[movies_cleaned['vote_average'] == top_rating]
top_movies[['title', 'vote_average', 'popularity', 'runtime']].head()
# Out:
#                                               title  vote_average  popularity  \
# 1820                           Una flor en el barro          10.0      33.913
# 2170                             Female Boss Hooker          10.0      30.620
# 2495                                          Hubba          10.0      28.357
# 3397  William K. Dozier III’s Version of –The Raven          10.0      23.999
# 3941   Beautiful Breasts Serenade: Erotic Fair Skin          10.0      22.176
#
#       runtime
# 1820        0
# 2170       76
# 2495      133
# 3397        0
# 3941       70

# %%
top_movies.columns
# Out:
# Index(['title', 'adult', 'genres', 'original_language', 'popularity',
#        'release_date', 'runtime', 'vote_average', 'vote_count', 'actors',
#        'director', 'keywords', 'runtime_for_plot'],
#       dtype='object')

# %%
top_movies.head(10)
#Quick check to see if actors column is not a stringified list(which we did make sure to split in the first phase)
type(top_movies['actors'].iloc[0])
# Out:
# str

# %%
top_movies['actors'].isnull().sum()
# Out:
# 0

# %%
#Applying split function to non-null valus only
top_movies.loc[:,'actors'] = top_movies['actors'].apply(
    lambda x: x.split(', ') if isinstance( x, str) else x)
type(top_movies['actors'].iloc[0])
# Out:
# list

# %%
#Grouping runtime to vote_average, whilst taking the average of the runtime column to have a clean plot

#Since the graph is still cluttered, I am rounding the voting average
movies_cleaned.loc[:,'rounded_averages'] = movies_cleaned['vote_average'].round(1)

movies_cleaned.groupby('rounded_averages')['runtime'].mean().sort_index().plot(kind='line', marker= 'o', figsize = (10,5))
plt.title('Average runtime per Vote average')
plt.xlabel('Vote Average')
plt.ylabel('Runtime average (mins)')
plt.grid(True)
plt.show()
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_28332\968269319.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned.loc[:,'rounded_averages'] = movies_cleaned['vote_average'].round(1)

# %%
# Temporary fix for plotting
# Create a temporary copy for EDA
tmdb_temp = movies_cleaned.copy()

# %%
# Safely parse stringified lists into actual Python lists
tmdb_temp['genres'] = tmdb_temp['genres'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else (x if isinstance(x, list) else [])
)

tmdb_temp['actors'] = tmdb_temp['actors'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else (x if isinstance(x, list) else [])
)

# Extract main_genre (first genre in the list), fill NaNs with placeholder
tmdb_temp['main_genre'] = tmdb_temp['genres'].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else np.nan
)
if tmdb_temp['main_genre'].mode().empty:
    tmdb_temp['main_genre'].fillna("Unknown", inplace=True)
else:
    tmdb_temp['main_genre'].fillna(tmdb_temp['main_genre'].mode()[0], inplace=True)

# Extract main_actor (first actor in the list), fill NaNs with placeholder
tmdb_temp['main_actor'] = tmdb_temp['actors'].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else np.nan
)
if tmdb_temp['main_actor'].mode().empty:
    tmdb_temp['main_actor'].fillna("Unknown", inplace=True)
else:
    tmdb_temp['main_actor'].fillna(tmdb_temp['main_actor'].mode()[0], inplace=True)

# Count number of genres per movie
tmdb_temp['num_genres'] = tmdb_temp['genres'].apply(
    lambda x: len(x) if isinstance(x, list) else 0
)

# Count number of actors per movie
tmdb_temp['num_actors'] = tmdb_temp['actors'].apply(
    lambda x: len(x) if isinstance(x, list) else 0
)

# Quick sanity check
print(tmdb_temp['main_genre'].value_counts(dropna=False).head())
print(tmdb_temp['main_actor'].value_counts(dropna=False).head())
# Out:
# main_genre
# Drama        1847
# Action       1507
# Comedy       1464
# Animation     814
# Horror        812
# Name: count, dtype: int64
# main_actor
# Nicolas Cage    78
# Jackie Chan     49
# Tom Hanks       41
# Bruce Willis    40
# Adam Sandler    38
# Name: count, dtype: int64
# C:\Users\anshu\AppData\Local\Temp\ipykernel_28332\1769297161.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tmdb_temp['main_genre'].fillna(tmdb_temp['main_genre'].mode()[0], inplace=True)
# C:\Users\anshu\AppData\Local\Temp\ipykernel_28332\1769297161.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tmdb_temp['main_actor'].fillna(tmdb_temp['main_actor'].mode()[0], inplace=True)

# %%
#Creating a correlation matrix 
corr_matrix = tmdb_temp.drop(columns=['adult']).corr(numeric_only=True)
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix,annot=True, fmt ='.2f',cmap='coolwarm',linewidth=0.5)

plt.title('Correlation Matrix for numeric variables')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %%
#Checking Distributions for key features like, 'vote_average','runtime','popularity','vote_count'

#Creating 2x2 subplots
fig, axs= plt.subplots(2,2,figsize=(12,8))
#Distribution of vote_average
sns.histplot(tmdb_temp['vote_average'],bins=20, kde= True, ax=axs[0,0])
axs[0,0].set_title('Distribution of Vote Average')
#Distribution of runtime
sns.histplot(tmdb_temp['runtime'], bins=20, kde= True, ax= axs[0,1])
axs[0,1].set_title('Distribution of runtime')
#Distribution of popularity
sns.histplot(tmdb_temp['popularity'], bins=20, kde= True, ax= axs[1,0])
axs[1,0].set_title('Distribution of Popularity')
#Distribution of vote_count
sns.histplot(tmdb_temp['vote_count'], bins=20, kde= True, ax= axs[1,1])
axs[1,1].set_title('Distribution of Vote Count')
plt.tight_layout()
plt.show()

# %%
#Taking a look at the categorical data
movies_cleaned.select_dtypes(include='object').columns
# Out:
# Index(['title', 'genres', 'original_language', 'actors', 'director',
#        'keywords'],
#       dtype='object')

# %%
#Plotting Top 10 'main_genre' 
tmdb_temp['main_genre'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Genres')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
#Doing the same for 'main_actors', 'director', and 'original_language'
tmdb_temp['main_actor'].value_counts().head(10).plot(kind='bar')
plt.title('Top Actors')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
#Converting 'director' columns from a string to list 
#Importing ast to convert stringified lists into actual lists
#Reassigning director column with original data, (Replaced all director names with 'Unknown' accidently)
tmdb_temp.loc[:,'director']= movies_cleaned['director']

# %%
tmdb_temp.head()
# Out:
#                           title  adult  \
# 0  Aquaman and the Lost Kingdom  False
# 1                         Wonka  False
# 2                          Wish  False
# 3                     Migration  False
# 4                   The Marvels  False
#
#                                            genres original_language  \
# 0                    [Action, Adventure, Fantasy]                en
# 1                       [Comedy, Family, Fantasy]                en
# 2         [Animation, Family, Fantasy, Adventure]                en
# 3  [Animation, Adventure, Comedy, Family, Action]                en
# 4            [Science Fiction, Adventure, Action]                en
#
#    popularity release_date  runtime  vote_average  vote_count  \
# 0    5841.384   2023-12-20      124         7.013        1156
# 1    2333.391   2023-12-06      117         7.200        1660
# 2    1662.711   2023-11-13       95         6.638         538
# 3    1486.310   2023-12-06       83         7.830         390
# 4    1397.918   2023-11-08      105         6.415        1328
#
#                                               actors             director  \
# 0  [Jason Momoa, Patrick Wilson, Yahya Abdul-Mate...        ['James Wan']
# 1  [Timothée Chalamet, Calah Lane, Keegan-Michael...        ['Paul King']
# 2  [Ariana DeBose, Chris Pine, Alan Tudyk, Angeli...       ['Chris Buck']
# 3  [Kumail Nanjiani, Elizabeth Banks, Caspar Jenn...  ['Benjamin Renner']
# 4  [Brie Larson, Teyonah Parris, Iman Vellani, Za...      ['Nia DaCosta']
#
#                                             keywords  runtime_for_plot  \
# 0  ['superhero', 'secret society', 'half-brother'...               124
# 1  ['chocolate', 'musical', 'prequel', 'duringcre...               117
# 2  ['friendship', 'musical', 'computer animation'...                95
# 3  ['duck', 'migration', 'flight', 'anthropomorph...                83
# 4  ['hero', 'superhero', 'space travel', 'based o...               105
#
#    rounded_averages       main_genre         main_actor  num_genres  \
# 0               7.0           Action        Jason Momoa           3
# 1               7.2           Comedy  Timothée Chalamet           3
# 2               6.6        Animation      Ariana DeBose           4
# 3               7.8        Animation    Kumail Nanjiani           5
# 4               6.4  Science Fiction        Brie Larson           3
#
#    num_actors main_director
# 0           4       Unknown
# 1           4       Unknown
# 2           4       Unknown
# 3           4       Unknown
# 4           4       Unknown

# %%
tmdb_temp.drop(['main_director'], axis =1, inplace= True)

# %%
print(movies_cleaned['director'].head(10))
print(movies_cleaned['director'].apply(type).value_counts())
# Out:
# 0                ['James Wan']
# 1                ['Paul King']
# 2               ['Chris Buck']
# 3          ['Benjamin Renner']
# 4              ['Nia DaCosta']
# 5            ['Oliver Kienle']
# 6    ['Serikbol Utepbergenov']
# 7        ['Christopher Zalla']
# 8        ['Lakshya Raj Anand']
# 9             ['F. Gary Gray']
# Name: director, dtype: object
# director
# <class 'str'>    9566
# Name: count, dtype: int64

# %%
#Converting 'director' columns from a string to list 
#Importing ast to convert stringified lists into actual lists
#Reassigning director column with original data, (Replaced all director names with 'Unknown' accidently)
tmdb_temp.loc[:,'director']= movies_cleaned['director']

# %%
tmdb_temp.loc[:,'director']= tmdb_temp['director'].apply(
        lambda x: ast.literal_eval(x) if isinstance (x, str) and x.strip().startswith('[') else x)

# %%
movies_cleaned.loc[:,'director'] = movies_cleaned['director'].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else 'Unknown')

# %%
tmdb_temp['director'].value_counts().head(10).plot(kind='bar')
plt.title('Top Directors')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
tmdb_temp['original_language'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Languages')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# #EDA Summary
